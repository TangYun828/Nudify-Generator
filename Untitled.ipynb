# %%
python launch.py --listen 0.0.0.0 --port 7865 --nowebui --always-high-vram --share
# Out:
#   Cell In[1], line 1
#     python launch.py --listen 0.0.0.0 --port 7865 --nowebui --always-high-vram --share
#            ^
# SyntaxError: invalid syntax

# %%
python launch.py --listen 0.0.0.0 --port 7865 --nowebui --always-high-vram
# Out:
#   Cell In[2], line 1
#     python launch.py --listen 0.0.0.0 --port 7865 --nowebui --always-high-vram
#            ^
# SyntaxError: invalid syntax

# %%
python launch.py --listen 0.0.0.0 --port 7865 --share
# Out:
#   Cell In[3], line 1
#     python launch.py --listen 0.0.0.0 --port 7865 --share
#            ^
# SyntaxError: invalid syntax
